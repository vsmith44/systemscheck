# %% [markdown]
# # Systems Check
# ## What I Hope to get out of Data in Emerging Media and Technology:

# %% [markdown]
# 1. Learn about Anaconda/Jupyter Notebook
# 2. Learn moe about Data Analtics
# 3. Apply/expand current skills

# %% [markdown]
#     I hope that with this class I can take my current experience and apply it to this class. I hope to grasp a more concrete understanding about data analytics and learn Anaconda/Jupyter Notebook.

# %% [markdown]
# ![data%20analytics.jpg](attachment:data%20analytics.jpg)

# %% [markdown]
# ## Variable Assignment

# %%
v=2000;
print (v)
# Out:
# 2000

# %% [markdown]
# ## For Loop

# %%
colors = ["purple", "pink", "black"]
for y in colors:
    print (y)
# Out:
# purple
# pink
# black

# %% [markdown]
# ## Print Statement

# %%
print (y)
print (v)
# Out:
# black
# 2000

# %% [markdown]
# ## Return Statement

# %%
def return_state():
    b = 3
    c =5
    return b,c
print (return_state ())
# Out:
# (3, 5)
